# %%
import numpy as np
import matplotlib.pylab as plt

import dm_models as dmm
from dm_models import dRdErSHM


#%matplotlib inline

# %%
target_atom = dmm.AGe # Germanium
mDM = 10 # GeV/c^2
sigma_n = 1e-42 # cross section for DM/nucleon interaction

for day in [0,60,120,180,240,300]:
    # Recoil energy range.
    Er = np.linspace(0.1,10.0,100)

    dRdEr = dRdErSHM(Er,day,target_atom,mDM,sigma_n) # SHM = Simple Halo Model (Maxwellian velocity distribution)
    
    xkeVee = dmm.quench_keVr_to_keVee(Er)
    
    plt.plot(xkeVee,dRdEr)
    
#plt.xlim(0.9,1.1)
#plt.ylim(0.02,0.04)

# %% [markdown]
# # Your goal, using another set of code, is to generate 10000 events, assuming they were in the CoGeNT detector. So, keVee (energy range from 0.5 - 3 keVee and over the course of 4 years.

# %%
maxpts = 1000
xpts = [] # These are the points I ``accept"
max_prob = 0.07
energies = []
days = []

npts = 0
while npts < maxpts:
    
    e = (2.5*np.random.random() + 0.5) # This is the energy
    t = (4*365.0)*np.random.random()
    
    e = dmm.quench_keVee_to_keVr(e)
    
    prob = dRdErSHM(e,t,target_atom,mDM,sigma_n)
    #prob = dmm.quench_keVr_to_keVee(Er)
    
    #print prob
    
    probtest = max_prob*np.random.random() # This is to see whether or not we keep x!
    
    if probtest<prob:
        energies.append(e)
        days.append(t)
        npts += 1

# %%
h = plt.hist(energies,bins=50)

# %%
h = plt.hist(days,bins=50)

# %%
import numpy as np
from cogent_stuff import *

# Using Nicole's simulated stuff
fast_mean_rel_k = [0.431998,-1.525604,-0.024960]
fast_sigma_rel_k = [-0.014644,5.745791,-6.168695]
fast_num_rel_k = [-0.261322,5.553102,-5.9144]

mu0 = [0.374145,0.628990,-1.369876]
sigma0 = [1.383249,0.495044,0.263360]

rise_time = 2.0
energy = 1.0
rt_fast = rise_time_prob_fast_exp_dist(rise_time,energy,mu0,sigma0,fast_mean_rel_k,fast_sigma_rel_k,fast_num_rel_k,0,7)

print rt_fast
# Out:
# 0.084025488053

# %%
rise_time = np.linspace(0,7,1000)

plt.figure(figsize=(16,8))
    
for energies in [0.5,1.0,1.5,2.0,2.5]:
    energy = energies*np.ones(1000)
    rtf = rise_time_prob_fast_exp_dist(rise_time,energy,mu0,sigma0,fast_mean_rel_k,fast_sigma_rel_k,fast_num_rel_k,0,7)


    plot(rise_time,rtf)

# %%
maxpts = 1000
xpts = [] # These are the points I ``accept"
max_prob = 0.07*4.0
energies = []
days = []
rise_times = []

npts = 0
while npts < maxpts:
    
    e = (2.5*np.random.random() + 0.5) # This is the energy
    t = (4*365.0)*np.random.random()
    rt = (6.0)*np.random.random()
    
    re = dmm.quench_keVee_to_keVr(e)
    
    prob = dRdErSHM(re,t,target_atom,mDM,sigma_n)
    rtf = rise_time_prob_fast_exp_dist(rt,e,mu0,sigma0,fast_mean_rel_k,fast_sigma_rel_k,fast_num_rel_k,0,7)
    
    prob *= rtf

    #prob = dmm.quench_keVr_to_keVee(Er)
    
    #print prob
    
    probtest = max_prob*np.random.random() # This is to see whether or not we keep x!
    
    if probtest<prob:
        energies.append(e)
        days.append(t)
        rise_times.append(rt)
        npts += 1

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,3,1)
plt.hist(rise_times,bins=100)
plt.subplot(1,3,2)
plt.hist(energies,bins=100)
plt.subplot(1,3,3)
plt.hist(days,bins=100)
# Out:
# (array([  5.,  10.,   7.,  12.,   8.,  14.,  10.,   7.,  19.,   9.,  14.,
#          12.,  12.,   6.,  12.,  20.,   9.,  11.,  12.,  13.,  11.,   8.,
#           8.,  15.,  14.,   4.,   4.,   9.,  11.,  10.,   6.,   7.,  11.,
#           6.,   8.,   5.,  11.,   8.,   7.,  13.,   4.,   6.,  12.,   5.,
#           9.,   8.,   9.,   8.,   9.,  10.,   9.,  12.,   9.,  12.,   8.,
#          11.,  10.,   4.,  10.,  12.,  12.,  11.,  14.,  14.,  10.,  17.,
#           8.,  15.,   9.,  13.,   6.,  11.,  11.,  17.,  12.,   9.,  13.,
#           7.,  12.,   8.,   1.,   9.,  20.,   6.,   9.,   9.,   9.,  15.,
#          11.,  11.,  12.,   8.,   8.,  11.,   7.,   9.,   9.,   9.,  14.,
#           9.]), array([  2.71722063e-01,   1.48685007e+01,   2.94652793e+01,
#           4.40620579e+01,   5.86588364e+01,   7.32556150e+01,
#           8.78523936e+01,   1.02449172e+02,   1.17045951e+02,
#           1.31642729e+02,   1.46239508e+02,   1.60836287e+02,
#           1.75433065e+02,   1.90029844e+02,   2.04626622e+02,
#           2.19223401e+02,   2.33820180e+02,   2.48416958e+02,
#           2.63013737e+02,   2.77610515e+02,   2.92207294e+02,
#           3.06804073e+02,   3.21400851e+02,   3.35997630e+02,
#           3.50594408e+02,   3.65191187e+02,   3.79787966e+02,
#           3.94384744e+02,   4.08981523e+02,   4.23578301e+02,
#           4.38175080e+02,   4.52771859e+02,   4.67368637e+02,
#           4.81965416e+02,   4.96562194e+02,   5.11158973e+02,
#           5.25755752e+02,   5.40352530e+02,   5.54949309e+02,
#           5.69546087e+02,   5.84142866e+02,   5.98739645e+02,
#           6.13336423e+02,   6.27933202e+02,   6.42529980e+02,
#           6.57126759e+02,   6.71723537e+02,   6.86320316e+02,
#           7.00917095e+02,   7.15513873e+02,   7.30110652e+02,
#           7.44707430e+02,   7.59304209e+02,   7.73900988e+02,
#           7.88497766e+02,   8.03094545e+02,   8.17691323e+02,
#           8.32288102e+02,   8.46884881e+02,   8.61481659e+02,
#           8.76078438e+02,   8.90675216e+02,   9.05271995e+02,
#           9.19868774e+02,   9.34465552e+02,   9.49062331e+02,
#           9.63659109e+02,   9.78255888e+02,   9.92852667e+02,
#           1.00744945e+03,   1.02204622e+03,   1.03664300e+03,
#           1.05123978e+03,   1.06583656e+03,   1.08043334e+03,
#           1.09503012e+03,   1.10962690e+03,   1.12422367e+03,
#           1.13882045e+03,   1.15341723e+03,   1.16801401e+03,
#           1.18261079e+03,   1.19720757e+03,   1.21180435e+03,
#           1.22640112e+03,   1.24099790e+03,   1.25559468e+03,
#           1.27019146e+03,   1.28478824e+03,   1.29938502e+03,
#           1.31398180e+03,   1.32857857e+03,   1.34317535e+03,
#           1.35777213e+03,   1.37236891e+03,   1.38696569e+03,
#           1.40156247e+03,   1.41615925e+03,   1.43075602e+03,
#           1.44535280e+03,   1.45994958e+03]), <a list of 100 Patch objects>)

# %%
def gen_shm_data(number_of_events,max_days,massDM,sigma_n,name_of_output_file):
    
    return 1
