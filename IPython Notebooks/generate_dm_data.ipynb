# %%
import numpy as np
import matplotlib.pylab as plt

import dm_models as dmm
from dm_models import dRdErSHM


#%matplotlib inline

# %%
target_atom = dmm.AGe # Germanium
mDM = 10 # GeV/c^2
sigma_n = 1e-42 # cross section for DM/nucleon interaction

for day in [0,60,120,180,240,300]:
    # Recoil energy range.
    Er = np.linspace(0.1,10.0,100)

    dRdEr = dRdErSHM(Er,day,target_atom,mDM,sigma_n) # SHM = Simple Halo Model (Maxwellian velocity distribution)
    
    xkeVee = dmm.quench_keVr_to_keVee(Er)
    
    plt.plot(xkeVee,dRdEr)
    
#plt.xlim(0.9,1.1)
#plt.ylim(0.02,0.04)

# %% [markdown]
# # Your goal, using another set of code, is to generate 10000 events, assuming they were in the CoGeNT detector. So, keVee (energy range from 0.5 - 3 keVee and over the course of 4 years.

# %%
maxpts = 1000
xpts = [] # These are the points I ``accept"
max_prob = 0.07
energies = []
days = []

npts = 0
while npts < maxpts:
    
    e = (2.5*np.random.random() + 0.5) # This is the energy
    t = (4*365.0)*np.random.random()
    
    e = dmm.quench_keVee_to_keVr(e)
    
    prob = dRdErSHM(e,t,target_atom,mDM,sigma_n)
    #prob = dmm.quench_keVr_to_keVee(Er)
    
    #print prob
    
    probtest = max_prob*np.random.random() # This is to see whether or not we keep x!
    
    if probtest<prob:
        energies.append(e)
        days.append(t)
        npts += 1

# %%
h = plt.hist(energies,bins=50)

# %%
h = plt.hist(days,bins=50)

# %%
import numpy as np
from cogent_stuff import *

# Using Nicole's simulated stuff
fast_mean_rel_k = [0.431998,-1.525604,-0.024960]
fast_sigma_rel_k = [-0.014644,5.745791,-6.168695]
fast_num_rel_k = [-0.261322,5.553102,-5.9144]

mu0 = [0.374145,0.628990,-1.369876]
sigma0 = [1.383249,0.495044,0.263360]

rise_time = 2.0
energy = 1.0
rt_fast = rise_time_prob_fast_exp_dist(rise_time,energy,mu0,sigma0,fast_mean_rel_k,fast_sigma_rel_k,fast_num_rel_k,0,7)

print rt_fast
# Out:
# 0.084025488053

# %%
rise_time = np.linspace(0,7,1000)

plt.figure(figsize=(16,8))
    
for energies in [0.5,1.0,1.5,2.0,2.5]:
    energy = energies*np.ones(1000)
    rtf = rise_time_prob_fast_exp_dist(rise_time,energy,mu0,sigma0,fast_mean_rel_k,fast_sigma_rel_k,fast_num_rel_k,0,7)


    plot(rise_time,rtf)

# %%
maxpts = 1000
xpts = [] # These are the points I ``accept"
max_prob = 0.07*4.0
energies = []
days = []
rise_times = []

npts = 0
while npts < maxpts:
    
    e = (2.5*np.random.random() + 0.5) # This is the energy
    t = (4*365.0)*np.random.random()
    rt = (6.0)*np.random.random()
    
    re = dmm.quench_keVee_to_keVr(e)
    
    prob = dRdErSHM(re,t,target_atom,mDM,sigma_n)
    rtf = rise_time_prob_fast_exp_dist(rt,e,mu0,sigma0,fast_mean_rel_k,fast_sigma_rel_k,fast_num_rel_k,0,7)
    
    prob *= rtf

    #prob = dmm.quench_keVr_to_keVee(Er)
    
    #print prob
    
    probtest = max_prob*np.random.random() # This is to see whether or not we keep x!
    
    if probtest<prob:
        energies.append(e)
        days.append(t)
        rise_times.append(rt)
        npts += 1

# %%
plt.figure(figsize=(20,8))
plt.subplot(1