# %%
import numpy as np
import lichen.lichen as lch
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
file0 = np.loadtxt('sample_surf_4482_4083_flat_3140_2926_lshell_975_842_0996.dat')
file1 = np.loadtxt('sample_surf_4482_4084_flat_3140_2830_lshell_975_865_0995.dat')
file2 = np.loadtxt('sample_surf_4482_4094_flat_3140_2911_lshell_975_848_0997.dat')
file3 = np.loadtxt('sample_surf_4482_4104_flat_3140_2908_lshell_975_907_0999.dat')
file4 = np.loadtxt('sample_surf_4482_4172_flat_3140_2913_lshell_975_820_0998.dat')

# %%
# This function takes an MC file and creates a histogram of the days, energies and rise times

def MC_hist(FILE,bin_num):
    days = FILE[:,0]
    energies = FILE[:,1]
    RiseTimes = FILE[:,2]
    
    plt.figure()
    days_hist = lch.hist_err(days,bins=bin_num)
    plt.title("Days")
    
    plt.figure()
    energies_hist = lch.hist_err(energies,bins=bin_num)
    plt.title("Energies")
    
    plt.figure()
    RiseTime_hist = lch.hist_err(RiseTimes,bins=bin_num)
    plt.title("Rise Times")
    
MC_hist(file0,50)
